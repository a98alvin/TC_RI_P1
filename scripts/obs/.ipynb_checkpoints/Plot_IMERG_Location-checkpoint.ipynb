# %%
# Import libraries
import pandas as pd
import datetime as dt
import os
import h5py
import numpy as np
import sys
sys.path.insert(0, '/Users/acheung/TC_RI_P1/scripts/Useful Functions/')
from distance import distance_calculator
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from metpy.plots import ctables
cmap = ctables.registry.get_colortable('precipitation')
import xarray as xr

# %%
# Enter time and Location

start_str = "2022-11-09 00:00:00"
end_str = "2022-11-12 00:00:00"

times_pd = pd.date_range(start=start_str,end=end_str, freq='30min')
times_pd = times_pd[0:-1]
desired_lon = -81.38
desired_lat = 28.54

# %%
filepaths = []
for i in times_pd: # Download all the desired IMERG Images
    # If IMERG file does not exist, download it
    
    year = i.year
    day_of_year = i.strftime('%j')
    day_stripped = i.strftime('%Y%m%d')
    time_stripped = i.strftime('%H%M%S')
    min_of_day = str(i.hour*60 + i.minute).zfill(4)
    end_time_stripped = (i+dt.timedelta(minutes=29,seconds=59)).strftime('%H%M%S')
        
    IMERG_file_path = '/Users/acheung/data/IMERG/'+str(year)+'/'+day_of_year+'/'+\
            '3B-HHR.MS.MRG.3IMERG.'+day_stripped+'-S'+time_stripped+'-E'+end_time_stripped+\
            '.'+min_of_day+'.V07B.HDF5'  

# If day directory does not exist, make day directory
    if os.path.exists('/Users/acheung/data/IMERG/'+str(year)) == False:
        os.mkdir('/Users/acheung/data/IMERG/'+str(year))

    if os.path.exists('/Users/acheung/data/IMERG/'+str(year)+'/'+day_of_year) == False:
        os.mkdir('/Users/acheung/data/IMERG/'+str(year)+'/'+day_of_year)

    if os.path.exists(IMERG_file_path) == False:
        url_desired = "https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_L3/GPM_3IMERGHH.07/"\
            +str(year)+'/'+day_of_year+'/'+'3B-HHR.MS.MRG.3IMERG.'+day_stripped+'-S'+time_stripped+\
            '-E'+end_time_stripped+'.'+min_of_day+'.V07B.HDF5'
        os.chdir('/Users/acheung/data/IMERG/'+str(year)+'/'+day_of_year)

        os.system('wget --load-cookies ~/.urs_cookies --save-cookies ~/.urs_cookies --keep-session-cookies '
                  + url_desired)
    filepaths.append(IMERG_file_path)

# %%
for case_loop in range(len(filepaths)): # Run all
# for case_loop in [18]: # Run all
    fn = filepaths[case_loop]
    print(fn)
    try:
        f = h5py.File(fn, 'r')
    except: # If the file is corrupt, remove and re-download
        os.system('rm ' + fn)
        os.chdir(fn[0:35])
        new_url = 'https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_L3/GPM_3IMERGHH.07/' + fn[26:]
        os.system('wget --load-cookies ~/.urs_cookies --save-cookies ~/.urs_cookies --keep-session-cookies '
                  + new_url)
        f = h5py.File(fn, 'r')
        
    # Work on precip file
    groups = [ x for x in f.keys() ]
    # print(groups)
    gridMembers = [ x for x in f['Grid'] ]
    # print(gridMembers)

    # Get the precipitation, latitude, and longitude variables
    precip = f['Grid/precipitation'][0][:][:]
    precip = np.transpose(precip)
    precip[precip<-999]=np.nan

    theLats = f['Grid/lat'][:]
    theLons = f['Grid/lon'][:]
    x, y = np.float32(np.meshgrid(theLons, theLats))

    # Find index closest to interpolated best-track center or 2-km radar center
    distance_arr = distance_calculator(x, y,(desired_lon,desired_lat))

    abs_dist_arr = (abs(distance_arr))

    min_dist_ind = np.where(abs_dist_arr == np.nanmin(abs_dist_arr))
    
    # Slice arrays to within 30 indices of desired center

    sliced_lon_grid = x[min_dist_ind[0][0]-30:min_dist_ind[0][0]+30,min_dist_ind[1][0]-30:min_dist_ind[1][0]+30]

    sliced_lat_grid = y[min_dist_ind[0][0]-30:min_dist_ind[0][0]+30,min_dist_ind[1][0]-30:min_dist_ind[1][0]+30]

    sliced_precip = precip[min_dist_ind[0][0]-30:min_dist_ind[0][0]+30,min_dist_ind[1][0]-30:min_dist_ind[1][0]+30]

    if case_loop == 0:
        total_precip = sliced_precip * 0.5
    else:
        total_precip = total_precip + (sliced_precip * 0.5)
# Out:
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S000000-E002959.0000.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S003000-E005959.0030.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S010000-E012959.0060.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S013000-E015959.0090.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S020000-E022959.0120.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S023000-E025959.0150.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S030000-E032959.0180.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S033000-E035959.0210.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S040000-E042959.0240.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S043000-E045959.0270.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S050000-E052959.0300.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S053000-E055959.0330.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S060000-E062959.0360.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S063000-E065959.0390.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S070000-E072959.0420.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S073000-E075959.0450.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S080000-E082959.0480.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S083000-E085959.0510.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S090000-E092959.0540.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S093000-E095959.0570.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S100000-E102959.0600.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S103000-E105959.0630.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S110000-E112959.0660.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S113000-E115959.0690.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S120000-E122959.0720.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S123000-E125959.0750.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S130000-E132959.0780.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S133000-E135959.0810.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S140000-E142959.0840.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S143000-E145959.0870.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S150000-E152959.0900.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S153000-E155959.0930.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S160000-E162959.0960.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S163000-E165959.0990.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S170000-E172959.1020.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S173000-E175959.1050.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S180000-E182959.1080.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S183000-E185959.1110.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S190000-E192959.1140.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S193000-E195959.1170.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S200000-E202959.1200.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S203000-E205959.1230.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S210000-E212959.1260.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S213000-E215959.1290.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S220000-E222959.1320.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S223000-E225959.1350.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S230000-E232959.1380.V07B.HDF5
# /Users/acheung/data/IMERG/2022/313/3B-HHR.MS.MRG.3IMERG.20221109-S233000-E235959.1410.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S000000-E002959.0000.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S003000-E005959.0030.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S010000-E012959.0060.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S013000-E015959.0090.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S020000-E022959.0120.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S023000-E025959.0150.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S030000-E032959.0180.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S033000-E035959.0210.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S040000-E042959.0240.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S043000-E045959.0270.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S050000-E052959.0300.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S053000-E055959.0330.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S060000-E062959.0360.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S063000-E065959.0390.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S070000-E072959.0420.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S073000-E075959.0450.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S080000-E082959.0480.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S083000-E085959.0510.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S090000-E092959.0540.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S093000-E095959.0570.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S100000-E102959.0600.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S103000-E105959.0630.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S110000-E112959.0660.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S113000-E115959.0690.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S120000-E122959.0720.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S123000-E125959.0750.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S130000-E132959.0780.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S133000-E135959.0810.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S140000-E142959.0840.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S143000-E145959.0870.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S150000-E152959.0900.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S153000-E155959.0930.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S160000-E162959.0960.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S163000-E165959.0990.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S170000-E172959.1020.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S173000-E175959.1050.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S180000-E182959.1080.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S183000-E185959.1110.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S190000-E192959.1140.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S193000-E195959.1170.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S200000-E202959.1200.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S203000-E205959.1230.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S210000-E212959.1260.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S213000-E215959.1290.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S220000-E222959.1320.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S223000-E225959.1350.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S230000-E232959.1380.V07B.HDF5
# /Users/acheung/data/IMERG/2022/314/3B-HHR.MS.MRG.3IMERG.20221110-S233000-E235959.1410.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S000000-E002959.0000.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S003000-E005959.0030.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S010000-E012959.0060.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S013000-E015959.0090.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S020000-E022959.0120.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S023000-E025959.0150.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S030000-E032959.0180.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S033000-E035959.0210.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S040000-E042959.0240.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S043000-E045959.0270.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S050000-E052959.0300.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S053000-E055959.0330.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S060000-E062959.0360.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S063000-E065959.0390.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S070000-E072959.0420.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S073000-E075959.0450.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S080000-E082959.0480.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S083000-E085959.0510.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S090000-E092959.0540.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S093000-E095959.0570.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S100000-E102959.0600.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S103000-E105959.0630.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S110000-E112959.0660.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S113000-E115959.0690.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S120000-E122959.0720.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S123000-E125959.0750.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S130000-E132959.0780.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S133000-E135959.0810.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S140000-E142959.0840.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S143000-E145959.0870.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S150000-E152959.0900.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S153000-E155959.0930.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S160000-E162959.0960.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S163000-E165959.0990.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S170000-E172959.1020.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S173000-E175959.1050.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S180000-E182959.1080.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S183000-E185959.1110.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S190000-E192959.1140.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S193000-E195959.1170.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S200000-E202959.1200.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S203000-E205959.1230.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S210000-E212959.1260.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S213000-E215959.1290.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S220000-E222959.1320.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S223000-E225959.1350.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S230000-E232959.1380.V07B.HDF5
# /Users/acheung/data/IMERG/2022/315/3B-HHR.MS.MRG.3IMERG.20221111-S233000-E235959.1410.V07B.HDF5

# %%
# Make the figure larger
fig = plt.figure(figsize=(10,7))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
clevs=[0.01,0.10,0.25,0.5,1,1.5,2,3,4,5,6,7,8,10,12,14,16,18,20,24,28,32,36,40]
imerg_plot = ax.contourf(sliced_lon_grid,sliced_lat_grid,total_precip/25.4,
            transform = ccrs.PlateCarree(),levels=np.arange(0,10.1,1),cmap='jet') # Convert units from mm to inches by dividing

# Add coastlines
# ax.coastlines()
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.COASTLINE)
plt.colorbar(imerg_plot,label='Precipitation (in)')
plt.title('start = ' + start_str + ', end = ' + end_str)
# Out:
# Text(0.5, 1.0, 'start = 2022-11-09 00:00:00, end = 2022-11-12 00:00:00')

# %%
sliced_lon_grid,sliced_lat_grid,total_precip
# Out:
# (array([[-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ],
#         [-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ],
#         [-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ],
#         ...,
#         [-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ],
#         [-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ],
#         [-84.35    , -84.25    , -84.15    , ..., -78.65    , -78.549995,
#          -78.45    ]], dtype=float32),
#  array([[25.55    , 25.55    , 25.55    , ..., 25.55    , 25.55    ,
#          25.55    ],
#         [25.65    , 25.65    , 25.65    , ..., 25.65    , 25.65    ,
#          25.65    ],
#         [25.75    , 25.75    , 25.75    , ..., 25.75    , 25.75    ,
#          25.75    ],
#         ...,
#         [31.25    , 31.25    , 31.25    , ..., 31.25    , 31.25    ,
#          31.25    ],
#         [31.349998, 31.349998, 31.349998, ..., 31.349998, 31.349998,
#          31.349998],
#         [31.449999, 31.449999, 31.449999, ..., 31.449999, 31.449999,
#          31.449999]], dtype=float32),
#  array([[  5.850001 ,   6.5050006,   8.664999 , ...,  15.079999 ,
#           18.314995 ,  21.285004 ],
#         [  6.700001 ,   8.139999 ,   7.010001 , ...,  27.385    ,
#           20.999996 ,  21.685    ],
#         [  7.905    ,   8.635    ,   9.739999 , ...,  29.255    ,
#           23.659998 ,  26.984999 ],
#         ...,
#         [ 31.669994 ,  32.599995 ,  33.15     , ...,  92.545006 ,
#           88.66001  ,  85.729996 ],
#         [ 32.139996 ,  30.859995 ,  32.124996 , ...,  98.604996 ,
#           85.98001  ,  82.67     ],
#         [ 32.140003 ,  32.030003 ,  32.959995 , ..., 102.984985 ,
#           84.91999  ,  73.405014 ]], dtype=float32))

# %%
da = xr.DataArray(
    data=total_precip,
    dims=["lon", "lat"],
    coords=dict(
        lon=(["lon", "lat"], sliced_lon_grid),
        lat=(["lon", "lat"], sliced_lat_grid),
        time='start = ' + start_str + ', end = ' + end_str,
    ),
    attrs=dict(
        description="IMERG Precip Total",
        units="mm",
    ),
)

da.to_netcdf('/Users/acheung/data/intermediates/start = ' + start_str + ', end = ' + end_str + 'imerg.nc')
